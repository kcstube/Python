# %% [markdown]
# ## タプル

# %%
t = (12345, 54321, 'Hello')

# %%
t
# Out:
# (12345, 54321, 'Hello')

# %%
t[2]
# Out:
# 'Hello'

# %%
t[0] = 6789
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-0425b079825d> in <module>()
# ----> 1 t[0] = 6789
#
# TypeError: 'tuple' object does not support item assignment

# %%
x = (1)
x
# Out:
# 1

# %%
x = (1,)

# %%
x
# Out:
# (1,)

# %% [markdown]
# pack, unpack

# %%
t = (1, 2, 3)

# %%
x, y, z = t

# %%
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
z
# Out:
# 3

# %%
x, y, z = 1, 2, 3

# %%
x
# Out:
# 1

# %%
a = 1, 2, 3

# %%
a
# Out:
# (1, 2, 3)

# %% [markdown]
# ## 集合
#
# 集合とは、重複する要素をもたない、順序づけられていない要素の集まり

# %%
a = {1,2,3}

# %%
b = {1,4,2}

# %%
b
# Out:
# {1, 2, 4}

# %%
set('letter')
# Out:
# {'e', 'l', 'r', 't'}

# %%
a = {1,2}
b = {2,3}

# %% [markdown]
# 積集合

# %%
a & b
# Out:
# {2}

# %% [markdown]
# 和集合

# %%
a | b
# Out:
# {1, 2, 3}

# %%
a.add(3)

# %%
a
# Out:
# {1, 2, 3}

# %%
a.remove(1)
a
# Out:
# {2, 3}

# %%
a[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-30-6a1284577a36> in <module>()
# ----> 1 a[0]
#
# TypeError: 'set' object is not subscriptable
