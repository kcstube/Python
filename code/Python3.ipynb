# %% [markdown]
# ## 変数と代入

# %%
1 + 1
# Out:
# 2

# %%
a = 2

# %%
a
# Out:
# 2

# %%
a + 1
# Out:
# 3

# %%
a
# Out:
# 2

# %%
a = a + 1

# %%
a
# Out:
# 3

# %%
1 == 1
# Out:
# True

# %%
a = 1
b = 2
c = a + b

# %%
c
# Out:
# 3

# %% [markdown]
# ## 変数の命名規則

# %%
a = 1

# %%
A = 2

# %%
A
# Out:
# 2

# %%
abc = 3

# %%
abc
# Out:
# 3

# %%
変数 = 1
変数
# Out:
# 1

# %%
a1 = 3

# %%
a1
# Out:
# 3

# %%
1a = 3
# Out:
#   File "<ipython-input-22-cb8215583cff>", line 1
#     1a = 3
#      ^
# SyntaxError: invalid syntax

# %%
if = 3
if
# Out:
#   File "<ipython-input-23-c657fd12d24a>", line 1
#     if = 3
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## もっと詳しく(代入)

# %%
a = 1

# %%
x, y, z = 1, 2, 3

# %%
x
# Out:
# 1

# %%
y
# Out:
# 2

# %%
z
# Out:
# 3

# %%
a = 'Hello World'
print(a)
# Out:
# Hello World

# %%
a = [1,2,3]

# %%
a[2]
# Out:
# 3

# %%
print(a)
# Out:
# [1, 2, 3]

# %% [markdown]
# ## 第3回演習問題

# %%
x = 2
y = x
x = 3

# %%
x
# Out:
# 3

# %%
y
# Out:
# 2

# %%
x = [2]
y = x
x[0] = 3

# %%
x
# Out:
# [3]

# %%
y
# Out:
# [3]
