# %% [markdown]
# ## 文字列操作 #1

# %%
'Hello World'
# Out:
# 'Hello World'

# %%
a = "I say 'Hello World'."
print(a)
# Out:
# I say 'Hello World'.

# %%
'I say 'Hello World'.'
# Out:
#   File "<ipython-input-3-dcabf6994f50>", line 1
#     'I say 'Hello World'.'
#                 ^
# SyntaxError: invalid syntax

# %%
b = 'I say "Hello World"'
print(b)
# Out:
# I say "Hello World"

# %%
c = """Hello. My name is Besshy.
I am a student of Keio University.
I like programming and science."""

print(c)
# Out:
# Hello. My name is Besshy.
# I am a student of Keio University.
# I like programming and science.

# %%
c
# Out:
# 'Hello. My name is Besshy.\nI am a student of Keio University.\nI like programming and science.'

# %% [markdown]
# ## エスケープ文字

# %%
d = "Hello. My name is Besshy.\n I am a student of Keio University"

# %%
print(d)
# Out:
# Hello. My name is Besshy.
#  I am a student of Keio University

# %%
print("Hello World")
print("\tHello World")
# Out:
# Hello World
# 	Hello World

# %%
e = "Hello. My name is Besshy. \
I am a student of Keio University."

# %%
print(e)
# Out:
# Hello. My name is Besshy. I am a student of Keio University.
