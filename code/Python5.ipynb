# %% [markdown]
# ## 文字列操作 #2

# %%
'Hello' + 'World'
# Out:
# 'HelloWorld'

# %%
'Hello ' + 'World'
# Out:
# 'Hello World'

# %%
a = 'Good '
b = 'Morning'
c = a + b
c
# Out:
# 'Good Morning'

# %%
'Hello ' * 4
# Out:
# 'Hello Hello Hello Hello '

# %%
start = 'Hello ' * 4 + '\n'
middle = 'Hey ' * 4 + '\n'
end = 'Goodbye'

print(start + middle + end)
# Out:
# Hello Hello Hello Hello
# Hey Hey Hey Hey
# Goodbye

# %% [markdown]
# ## 文字列内の文字へのアクセス

# %%
letters = 'abcdefghijklmnopqrstuvwxyz'

# %%
letters[0]
# Out:
# 'a'

# %%
letters[5]
# Out:
# 'f'

# %%
letters[-1]
# Out:
# 'z'

# %%
letters[-2]
# Out:
# 'y'

# %%
letters[100]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-82591940fd7b> in <module>()
# ----> 1 letters[100]
#
# IndexError: string index out of range

# %% [markdown]
# ## 文字列の書き換え、スライス

# %%
letters[0] = 'z'
letters
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-1b48e6263d5f> in <module>()
# ----> 1 letters[0] = 'z'
#       2 letters
#
# TypeError: 'str' object does not support item assignment

# %%
letters[12:15]
# Out:
# 'mno'

# %%
letters[0:26]
# Out:
# 'abcdefghijklmnopqrstuvwxyz'
