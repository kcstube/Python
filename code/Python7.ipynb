# %% [markdown]
# ## リスト操作 #1

# %%
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
weekdays
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

# %%
weekdays[0:2]
# Out:
# ['Monday', 'Tuesday']

# %%
weekdays[0] = 'Sunday'

# %%
weekdays
# Out:
# ['Sunday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']

# %%
today = ['Saturday', 1, 22, 2022]

# %%
today
# Out:
# ['Saturday', 1, 22, 2022]

# %%
yesterday = ['Friday', 1, 21, 2022]
tomorrow = ['Sunday', 1, 23, 2022]
three_days = [yesterday, today, tomorrow]
three_days
# Out:
# [['Friday', 1, 21, 2022], ['Saturday', 1, 22, 2022], ['Sunday', 1, 23, 2022]]

# %% [markdown]
# append, extend

# %%
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
weekend = ['Saturday', 'Sunday']

# %%
weekend.append('Monday')

# %%
weekend
# Out:
# ['Saturday', 'Sunday', 'Monday']

# %%
weekdays.extend(weekend)

# %%
weekdays
# Out:
# ['Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  'Saturday',
#  'Sunday',
#  'Monday']

# %%
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
weekend = ['Saturday', 'Sunday']

# %%
weekdays.append(weekend)
weekdays
# Out:
# ['Monday',
#  'Tuesday',
#  'Wednesday',
#  'Thursday',
#  'Friday',
#  ['Saturday', 'Sunday']]

# %%
weekdays = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday']
weekend = ['Saturday', 'Sunday']

# %%
weekdays += weekend
weekdays
# Out:
# ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# %%
a = 1
a = a + 1 
a
# Out:
# 2

# %%
a = 1
a += 1
a
# Out:
# 2
