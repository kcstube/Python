# %% [markdown]
# ## 辞書

# %%
color = {'red': 1, 'blue': 2, 'yellow': 3}

# %%
color
# Out:
# {'blue': 2, 'red': 1, 'yellow': 3}

# %%
color['red']
# Out:
# 1

# %%
color["green"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-4-e16f569947da> in <module>()
# ----> 1 color["green"]
#
# KeyError: 'green'

# %%
color.get('red')
# Out:
# 1

# %%
color.get('green')

# %%
color["green"] = 4
color
# Out:
# {'blue': 2, 'green': 4, 'red': 1, 'yellow': 3}

# %%
color.pop('red')
color
# Out:
# {'blue': 2, 'green': 4, 'yellow': 3}

# %%
color.clear()

# %%
color
# Out:
# {}

# %%
color = {'red': 1, 'blue': 2, 'yellow': 3}

# %%
color.keys()
# Out:
# dict_keys(['red', 'blue', 'yellow'])

# %%
color.values()
# Out:
# dict_values([1, 2, 3])

# %%
'red' in color.keys()
# Out:
# True

# %%
1 in color.values()
# Out:
# True

# %% [markdown]
# タプルはkeyにできるが、リストはkeyにできない。
#
# hash可能かどうかがkeyとして使えるかの条件

# %%
color = {["red", "blue"]: 1, "yellow": 2}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-f3d835a6baf7> in <module>()
# ----> 1 color = {["red", "blue"]: 1, "yellow": 2}
#
# TypeError: unhashable type: 'list'

# %%
color = {("red", "blue"): 1, "yellow": 2}

# %%
color
# Out:
# {('red', 'blue'): 1, 'yellow': 2}

# %%
color = {{1,2}: 'red', 3: 'blue'}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-b557c1ef7986> in <module>()
# ----> 1 color = {{1,2}: 'red', 3: 'blue'}
#
# TypeError: unhashable type: 'set'
