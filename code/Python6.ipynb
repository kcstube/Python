# %% [markdown]
# ## 文字列操作 #3

# %%
letters = 'abcdefghijklmnopqrstuvwxyz'

# %%
text = "Hello. My name is Besshy. I am a student of Keio University."

# %%
len(letters)
# Out:
# 26

# %%
empty = ''
len(empty)
# Out:
# 0

# %%
text.split('.')
# Out:
# ['Hello', ' My name is Besshy', ' I am a student of Keio University', '']

# %%
div_list = ['I', 'am', 'Besshy']
all_list = '\n'.join(div_list)
print(all_list)
# Out:
# I
# am
# Besshy

# %% [markdown]
# replace, str

# %%
name = 'Besshy'

# %%
name.replace('B', 'P')
# Out:
# 'Pesshy'

# %%
name.replace('s', 't', 1)
# Out:
# 'Betshy'

# %%
str(23)
# Out:
# '23'

# %%
start = 'I am '
end = ' years old'
age = 53

print(start + str(age) + end)
# Out:
# I am 53 years old
