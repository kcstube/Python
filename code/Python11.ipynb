# %% [markdown]
# if文

# %%
a = 200

if a == 100:
  print('a is 100')
else:
  print('a is not 100')
# Out:
# a is not 100

# %%
if False:
  print('a is 100')
else:
  print('a is not 100')
# Out:
# a is not 100

# %%
a = 400

if a == 100:
  print('a is 100')
elif a == 200:
  print('a is 200')
elif a == 300:
  print('a is 300')
else:
  print('a is over 300')
# Out:
# a is over 300

# %% [markdown]
# 比較演算子と論理演算子

# %%
100 == 100
# Out:
# True

# %%
100 != 100
# Out:
# False

# %%
200 > 100
# Out:
# True

# %%
100 < 200
# Out:
# True

# %%
a = 15
if (a > 10) and (a < 20):
  print("yes")
else:
  print('no')
# Out:
# yes

# %%
a = 30
if a < 10 or a > 20:
  print('yes')
else:
  print('no')
# Out:
# yes

# %%
a = 10
a is 10
# Out:
# True

# %%
a is not 10
# Out:
# False

# %%
a is None

# %%
a == None
# Out:
# False
